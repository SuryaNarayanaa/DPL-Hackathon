# %%
from IPython.display import Image, display

display(Image('EDA_finishing_positions.png'))
display(Image('EDA_grid_vs_finish.png'))
display(Image('Insights_constructor_dominance.png'))
display(Image('Insights_pit_stop_impact.png'))
display(Image('Problem_driver_win_ratio.png'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File d:\Miniconda\envs\Kumari\lib\site-packages\IPython\core\display.py:1045, in Image._data_and_metadata(self, always_both)
#    1044 try:
# -> 1045     b64_data = b2a_base64(self.data, newline=False).decode("ascii")
#    1046 except TypeError as e:
#
# TypeError: a bytes-like object is required, not 'str'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# File d:\Miniconda\envs\Kumari\lib\site-packages\IPython\core\formatters.py:974, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#     971     method = get_real_method(obj, self.print_method)
#     973     if method is not None:
# --> 974         return method(include=include, exclude=exclude)
#     975     return None
#     976 else:
#
# ...
